# %%
Frutas = ["manzana", "banana", "cereza", "durazno", "fresa"]
numeros = [10, 20, 30]
mixta = ["Ana"; 25, 1.75, True]
vacia = []

print (frutas)
print(len(frutas))

# %%
numero = [20, 30, 10, 50]

print(numeros)
numeros.append(60)
print(numeros)
numero.short()
print(numeros)
numeros.append(40)
print(numeros)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 numero = [20, 30, 10, 50]
#       2
# ----> 3 print(numeros)
#       4 numeros.append(60)
#       5 print(numeros)
#       6 numero.short()
#
# NameError: name 'numeros' is not defined

# %%
numeros = [30, 10, 20]
numeros.append(40)      # -> [30, 10, 20, 40]
numeros.sort()          # -> [10, 20, 30, 40]
numeros.remove(20)      # -> [10, 30, 40]
print(numeros)          # [10, 30, 40]
print(len(numeros))     # 3
# Out:
# [10, 30, 40]
# 3

# %%
filas = 3
columnas = 3

matriz = []
for f in range(filas):
    fila_actual = []
    for c in range(columnas):
        valor = int(input(f"valor para ({f}, {c}): "))
        fila_actual.append(valor)
    matriz.append(fila_actual)

print("Impresion de matriz:")
for f in range(filas):
    for c in range(columnas):
        print(matriz[f][c], end=" ")
    print()

# %%
dimension = int(input("Cuanta dimención: "))

matriz = []
for f in range(dimension):
    fila_actual = []
    for c in range(dimension):
        valor = 0
        if f == c:
            valor = 1
        fila_actual.append(valor)
    matriz.append(fila_actual)

    print("Imprecion de matriz:")
    for f in range(dimension):
        for c in range(dimension):
            print(matriz[f][c], end=" ")
        print()
# Out:
# Imprecion de matriz:
# 1 0 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 16
#      12
#      13     print("Imprecion de matriz:")
#      14     for f in range(dimension):
#      15         for c in range(dimension):
# ---> 16             print(matriz[f][c], end=" ")
#      17         print()
#
# IndexError: list index out of range

# %%
lista = []
contador  = 1
while True: 
    valor = int(input("Ingres5a número entre -10 y 10: "))
    if valor > -10 and valor < 10:    lista.append(valor)
    contador += 1
else:
    print("Rango incorrecto,ingrese un número entre -10 y 10")
    print(lista)
    for i in lista:
        if i < 0:
            print("Asteriscos negativos")
        elif i >0:
            print("Asteriscos positivos")
        else:
            print("|")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 lista = []
#       2 contador  = 1
#       3 while True:
# ----> 4     valor = int(input("Ingresa número entre -10 y 10: "))
#       5     if valor > -10 and valor < 10:    lista.append(valor)
#       6     contador += 1
#       7 else:
#
# ValueError: invalid literal for int() with base 10: ''
