# %% [markdown]
# Variables:Las variables en phyton son tipos datos que tienen diferente forma.
# -Numericas
# -Enteros
# -Flotantes
# -Cadenas de caracteres
# -Booleanos
# -Compuestos

# %%
Nombre = "Ricardo"
Edad = 45
Es_estudiante = True
Esta_activo = none

print(type(Nombre))
print(type(Edad))
print(type(Es_estudiante))
print(type(Esta_activo))
