# %% [markdown]
# Calculadora virtual

# %%
print(" Calculadora de uso de aplicacciones")

nombre = input("Cual es tu nombre?")

instagram = float(input("Horas que se usan Instagram"))
Tik_tok = float(input("Horas que se usan Tik tok"))
Youtube = float(input("Horas que se usan Youtube"))
videojuegos = float(input("Horas que se usan videojuegos"))
facebook = float(input("Horas que se usan Facebook"))

tiempo_total= instagram + Tik_tok + Youtube + videojuegos + facebook

porcentaje_redes = (tiempo_total / 24) * 100

print(f"\n--- Resultado ---")
print(f"usuario: {nombre}")
print(f"Tiempo total de uso de redes: {tiempo_total:.2f} horas")
print(f"Porcentaje de tiempo en redes: {porcentaje_redes:.2f}%")
# Out:
#  Calculadora de uso de aplicacciones
#
# --- Resultado ---
# usuario: D
# Tiempo total de uso de redes: 27.00 horas
# Porcentaje de tiempo en redes: 112.50%

# %% [markdown]
# Ejercicio extra #1

# %%
cuenta =  float(input("total de la cuenta: "))
propinas_porcentaje = float(input("Porcentaje de propina: "))
persona = int(input("numero de personas:"))

propina = cuenta + (cuenta * propinas_porcentaje / 100)
total = cuenta + propina
pago_por_persona = total / persona

print(f"--- Resultado ---")
print(f"total de la cuenta: ${cuenta:.2f}")
print(f"propina: ${propina:.2f}")
print(f"total a pagar: ${total:.2f}")
print(f"pago por persona: ${pago_por_persona:.2f}")
# Out:
# --- Resultado ---
# total de la cuenta: $422.00
# propina: $485.30
# total a pagar: $907.30
# pago por persona: $226.82

# %% [markdown]
# ejercicio extra #2

# %%
minutos = int(input("Total de minutos:"))
dias = minutos // 1440
minutos_restantes = minutos % 1440
horas = minutos_restantes // 60
minutos_finalaes = minutos_restantes % 60
print(f"--- Resultado ---")
print(f"Total de dias: {dias}")
print(f"Total de horas: {horas}")
# Out:
# --- Resultado ---
# Total de dias: 12
# Total de horas: 12

# %% [markdown]
# ejercicio extra #3

# %%
parcial1 = float(input("Parcial 1 (30%): "))
parcial2 = float(input("Parcial 2 (30%): "))
parcial3 = float(input("Parcial 3 (40%): "))

cal1 = parcial1 * 0.30
cal2 = parcial2 * 0.30
cal3 = parcial3 * 0.40

final = cal1 + cal2 + cal3

print(f"Tu calificación final es: {final:.2f}")
# Out:
# Tu calificación final es: 5.00

# %% [markdown]
# ejercicio extra #4

# %%
cantidad = float(input("Cantidad en MXN: "))
dolar = float(input("Tipo de cambio USD: "))
euro = float(input("Tipo de cambio EUR: "))

usd = cantidad / dolar
eur = cantidad / euro

print(f"${cantidad:.2f} MXN equivalen a:")
print(f"USD: {usd:.2f}")
print(f"EUR: {eur:.2f}")
# Out:
# $300.00 MXN equivalen a:
# USD: 13.64
# EUR: 27.27
