# %%
cucharas_azucar = 2
cliente_quierer;azucae = true

nombre_cliente = "fernando"
edad_cliente = 25
mayor_De_edad = true
if condicion:
    # Acción que se ejecuta si es VERDADERO
else:
    # Acción que se ejecuta si es FALSO

# %%
if ____________:
    print("Sirviendo café con licor ☕🍷")
else:
    print("Sirviendo café tradicional ☕")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 if ____________:
#       2     print("Sirviendo café con licor ☕🍷")
#       3 else:
#       4     print("Sirviendo café tradicional ☕")
#
# NameError: name '____________' is not defined
